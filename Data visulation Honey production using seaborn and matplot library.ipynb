# %% [markdown]
# # Data visulation Honey production using seaborn and matplot library

# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features

# %%
# sample
df.sample(5)
# Out:
#     state    numcol  yieldpercol   totalprod     stocks  priceperlb  \
# 549    CA  370000.0           48  17760000.0  3730000.0        1.65
# 547    AZ   23000.0           53   1219000.0   427000.0        1.55
# 309    HI    9000.0          131   1179000.0   283000.0        1.43
# 526    MT  157000.0           74  11618000.0  2905000.0        1.58
# 191    MN  117000.0           73   8541000.0  1110000.0        1.47
#
#       prodvalue  year
# 549  29304000.0  2011
# 547   1889000.0  2011
# 309   1686000.0  2005
# 526  18356000.0  2010
# 191  12555000.0  2002

# %%
# shape 


df.shape
# Out:
# (626, 8)

# %%
# info


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
# Dtypes

df.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
# Describe


df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
df.groupby('year').count()[['state']].plot(y='state',kind='pie',figsize=(6,6),autopct='%1.1f%%', legend = False)
# Out:
# <AxesSubplot:ylabel='state'>

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings

# %%
sns.displot(x=df['priceperlb'], kind= 'hist',bins = 30, kde = True)
plt.show()


# using Histogram,plot for ['priceperlb'] and the distribution of the graph is peak in somepoint.
# where the Priceperlb value in between 1.3 and 1.5 and count in between 50 to 60.
# so the graph is positively skewed.

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings

# %%
# plot the relationship b/w the varibles 'numcol' and 'prodval' through scatterplot.

plt.scatter(x=df['numcol'], y=df['prodvalue'])
plt.title('numcol vs prodvalue')
plt.show()

# The Relationship between 'numcol' and 'prodvalue' is directly related with the representation of graph'
# The values of numcol and prodvalue is merged in
# The Graph values is aslo gradually  increasing

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot,and write your findings.

# %%
sns.catplot(data=df, x='year', y='prodvalue', kind='box', height=5, aspect =1.2)
plt.show()

# Relation between the 'year' and 'prodvalue'is find using seaborn as sns
# Many outliers as obtain for data by using boxplot

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inference .(use columns 'numcol','yield percol',total prod,'prodvalue','year').

# %%
sns.pairplot(df[['numcol','yieldpercol','totalprod','prodvalue','year']],corner = True)


# 'Numcol','Totalprod','Prodvalue' ard positvely skewed
# 'Yieldpercol' are seems to be Normal Distribution graph.
# so the 'numcol','totalprod','Yieldpercol','prodvalue' seems to be positively related to each other .

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol','total prod','stocks','price per lb','prodvalue')

# %%
sns.heatmap(data=df[['numcol','yieldpercol','stocks','priceperlb','prodvalue']].corr(),annot = True,cmap='YlGnBu');

# The correlation  value between the columns ' numcol','yieldpercol','stocks','priceperlab','prodvalue'.
# the heatmap the values have been predicted
# Totalprod and numcol are positively skewed.
# priceperlb and yieldpercol are Negatively Skewed.
